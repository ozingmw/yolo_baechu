# %%
from diffusers import AutoPipelineForText2Image
import torch

pipeline = AutoPipelineForText2Image.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16).to("mps")
pipeline.load_lora_weights("./models/rate_5e-6/checkpoint-1600", weight_name="pytorch_lora_weights.safetensors")
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:06<00:00,  1.05it/s]

# %%
image = pipeline("a photo of cabbage base").images[0]
image
# Out:
# 100%|██████████| 50/50 [00:57<00:00,  1.14s/it]
# <PIL.Image.Image image mode=RGB size=512x512>
